# %% [markdown]
# # Amazon Web Scraper Project

# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib

# %%
URL = 'https://www.amazon.in/ASUS-Graphics-3-8-Slot-Axial-tech-Phase-Change/dp/B0DTHV8THW/ref=sr_1_2?crid=WSCN9KGN6ERZ&dib=eyJ2IjoiMSJ9.qO__7SX9ZwHXv0IxBb1fZ0SbfX7GMcmB3gG8dG0q_ivdLFF1bNyY_1W93Ibkz0PpuNUothNBzUAqMM9gYQFHRC45-kfKn6umH8Y4y8zpmiEpFsTYR-w7IwwElEwFF5Cb0UpFHUtkE9tKLSwbueSbWBKRtIasM-n-HZoZ-uACAsw196DGqQgNkF3sOeoPRVYgBqUO5eePFhm-KH6MPCMAXoqZ6_MTloNDQ-MVwE6sG9I.GOZgY_ZhpQIzxbT4tz_kVKQ0l87q1l3wpCY8M92_oT8&dib_tag=se&keywords=rtx+5090+graphic+card&qid=1763475295&sprefix=rtx+5090+g%2Caps%2C227&sr=8-2'

headers ={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36", "X-Amzn-Trace-Id": "Root=1-691c7ca3-23d6f11924fb47342cd88023"}
# https://httpbin.org/get - For headers

page = requests.get(URL, headers = headers)

soup1 = BeautifulSoup(page.content, 'html.parser')

soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')

title = soup2.find(id = 'productTitle').get_text().strip()

price = soup2.find(class_='a-price-whole')
if price:
    price = price.get_text()
else:
    price = None

print(title)
print(price)
# Out:
# ASUS ROG Astral GeForce RTX™ 5090 OC Edition Gaming Graphics Card (PCIe® 5.0, 32GB GDDR7, HDMI®/DP 2.1, 3.8-Slot, 4-Fan Design, Axial-tech Fans, Patented Vapor Chamber, Phase-Change GPU Thermal pad)
#
#                              4,29,499
#
#                               .

# %%
words = title.split()
short_title = ' '.join(words[:11])
clean_price = price.replace(".", "").strip() if price else None

print(short_title)
print(clean_price)
# Out:
# ASUS ROG Astral GeForce RTX™ 5090 OC Edition Gaming Graphics Card
# 4,29,499

# %%
today = datetime.date.today()
print(today)
# Out:
# 2025-11-18

# %%
import csv

header = ['Title', 'Price', 'Date']
data = [short_title, clean_price, today]

with open('Graphics_Card_Price.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Nizanth\Graphics_Card_Price.csv")
df
# Out:
#                                                Title     Price        Date
# 0  ASUS ROG Astral GeForce RTX™ 5090 OC Edition G...  4,29,499  2025-11-18
# 1  ASUS ROG Astral GeForce RTX™ 5090 OC Edition G...  4,29,499  2025-11-18

# %%
#append

with open('Graphics_Card_Price.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.in/ASUS-Graphics-3-8-Slot-Axial-tech-Phase-Change/dp/B0DTHV8THW/ref=sr_1_2?crid=WSCN9KGN6ERZ&dib=eyJ2IjoiMSJ9.qO__7SX9ZwHXv0IxBb1fZ0SbfX7GMcmB3gG8dG0q_ivdLFF1bNyY_1W93Ibkz0PpuNUothNBzUAqMM9gYQFHRC45-kfKn6umH8Y4y8zpmiEpFsTYR-w7IwwElEwFF5Cb0UpFHUtkE9tKLSwbueSbWBKRtIasM-n-HZoZ-uACAsw196DGqQgNkF3sOeoPRVYgBqUO5eePFhm-KH6MPCMAXoqZ6_MTloNDQ-MVwE6sG9I.GOZgY_ZhpQIzxbT4tz_kVKQ0l87q1l3wpCY8M92_oT8&dib_tag=se&keywords=rtx+5090+graphic+card&qid=1763475295&sprefix=rtx+5090+g%2Caps%2C227&sr=8-2'

    headers ={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36", "X-Amzn-Trace-Id": "Root=1-691c7ca3-23d6f11924fb47342cd88023"}

    page = requests.get(URL, headers = headers)

    soup1 = BeautifulSoup(page.content, 'html.parser')

    soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')

    title = soup2.find(id = 'productTitle').get_text().strip()

    price = soup2.find(class_='a-price-whole')
    if price:
        price = price.get_text()
    else:
        price = None
    words = title.split()
    short_title = ' '.join(words[:11])
    clean_price = price.replace(".", "").strip() if price else None

    today = datetime.date.today()
    print(today)

    import csv

    header = ['Title', 'Price', 'Date']
    data = [short_title, clean_price, today]

    with open('Graphics_Card_Price.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

        if(clean_price < 100000):
            send_mail()

# %%
while(True):
    check_price()
    time.sleep(5)

# %%
df = pd.read_csv(r"C:\Users\Nizanth\Graphics_Card_Price.csv")
df
# Out:
#                                                Title     Price        Date
# 0  ASUS ROG Astral GeForce RTX™ 5090 OC Edition G...  4,29,499  2025-11-18
# 1  ASUS ROG Astral GeForce RTX™ 5090 OC Edition G...  4,29,499  2025-11-18
# 2  ASUS ROG Astral GeForce RTX™ 5090 OC Edition G...  4,29,499  2025-11-18
# 3  ASUS ROG Astral GeForce RTX™ 5090 OC Edition G...  4,29,499  2025-11-18
# 4  ASUS ROG Astral GeForce RTX™ 5090 OC Edition G...  4,29,499  2025-11-18

# %%
def send_mail():
    import smtplib

    sender = "nizanthns10@gmail.com"
    receiver = "nizanthns10@gmail.com"
    app_password = "YOUR_16_DIGIT_APP_PASSWORD"

    server = smtplib.SMTP_SSL("smtp.gmail.com", 465)
    server.login(sender, app_password)

    subject = "The 5090 Graphics Card's price is below 1 lacs"
    body = (
        "Hey, This is the moment you have been waiting for. "
        "Now is your chance to buy the Graphics Card of your dreams. "
        "Don't mess it up!"
        "Link here: https://www.amazon.in/ASUS-Graphics-3-8-Slot-Axial-tech-Phase-Change/dp/B0DTHV8THW/ref=sr_1_2?crid=WSCN9KGN6ERZ&dib=eyJ2IjoiMSJ9.qO__7SX9ZwHXv0IxBb1fZ0SbfX7GMcmB3gG8dG0q_ivdLFF1bNyY_1W93Ibkz0PpuNUothNBzUAqMM9gYQFHRC45-kfKn6umH8Y4y8zpmiEpFsTYR-w7IwwElEwFF5Cb0UpFHUtkE9tKLSwbueSbWBKRtIasM-n-HZoZ-uACAsw196DGqQgNkF3sOeoPRVYgBqUO5eePFhm-KH6MPCMAXoqZ6_MTloNDQ-MVwE6sG9I.GOZgY_ZhpQIzxbT4tz_kVKQ0l87q1l3wpCY8M92_oT8&dib_tag=se&keywords=rtx+5090+graphic+card&qid=1763475295&sprefix=rtx+5090+g%2Caps%2C227&sr=8-2"
        "Haha April fool"
    )

    msg = f"Subject: {subject}\n\n{body}"

    server.sendmail(sender, receiver, msg)
    server.quit()
    
send_mail()
print("Email sent!")
